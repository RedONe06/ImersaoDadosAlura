# %% [markdown]
# <a href="https://colab.research.google.com/github/RedONe06/ImersaoDadosAlura/blob/main/NoteImoveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 Aula 1 - Imersão de dados (Alura)

# %% [markdown]
# Esta é a minha introdução ao Python, Pandas e a área de dados. Aqui estão minhas anotações e lembretes sobre a primeira aula da Imersão, junto com os desafios resolvidos e corrigidos junto à comunidade do evento.

# %%
import pandas as pd 
#importa a biblioteca (classe) panda que é capaz
#de ler dados (tem os métodos) e pd é um objeto "panda"
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv";
#caminho raw da minha base de dados tratada, exportada do github gist
dados = pd.read_csv(url);
#método read_csv(url) do objeto pd que vai ler o caminho da base de dados

#csv = comma-separated-values, o que dá pra ver pelo conteúdo do arquivo
#as **funções chamadas aqui vem do panda

# %%
dados.head() #imprime as 5 primeiras linhas da base de dados (a "cabeça")
#.head pode receber parâmetro para especificar a quantidade de linhas impressas
#.center pega valores do meio da tabela
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados #imprime todos os dados(em dataframe), ao final consta quantidade de row x columns
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados.sample(10)#imprime linha aleatória de dados, parâmetro quantidade de linhas
# Out:
#                                   Rua                Bairro     Cidade  \
# 7887                              NaN               Butantã  São Paulo
# 8763                 Avenida Euclides          Vila Fachini  São Paulo
# 2896  Rua Professor Luciano Gualberto        Jardim Morumbi  São Paulo
# 374     Rua Doutor Benedito Matarazzo   Parque Maria Helena  São Paulo
# 6742                              NaN       Vila Tramontano  São Paulo
# 2049                              NaN  Jardim das Bandeiras  São Paulo
# 8822      Rua Georgina de Albuquerque      Parque Jabaquara  São Paulo
# 9620                 Rua Monte Alegre              Perdizes  São Paulo
# 7304     Rua Brigadeiro Gama Barcelos      Parque Jabaquara  São Paulo
# 1276                              NaN              Vila Gea  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 7887       300        3          5      4
# 8763       141        3          2      2
# 2896      1000        5          7      4
# ...

# %%
type(dados) #mostra qual o tipo do dado
# Out:
# pandas.core.frame.DataFrame

# %%
dados["Bairro"] #navega entre dataseries = coluna singular
#timeseries = linha singular
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %%
dados["Bairro"][9393] #column x row 
#processo de slice = análise de um dado isolado
# Out:
# 'Quinta da Paineira'

# %%
dados.info() #traz informações sobre os dados
#mostra a quantidade de linhas e colunas direto
#tipo object é o String dentro do pandas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.Bairro #outra forma de visualizar o dataseries
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %%
#para tirar a média da metragem:
dados.Metragem.mean() #método mean(média) traz a média dos valores
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
dados["Bairro"] == "Vila Mariana" #teste pra vila mariana em todos os valores 
#e é dado em boolean
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
(dados["Bairro"] == "Vila Mariana")*1 #o multiplicar boolean por 1 ele me
#retorna em int, porém dtenho cerca de 9990 dados escondidos na tabela que podem
#ser true (1), portanto somamos o valor total para ver se o resultado != 0
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10003    0
# 10004    0
# 10005    0
# 10006    0
# 10007    0
# Name: Bairro, Length: 10008, dtype: int64

# %%
sum((dados["Bairro"] == "Vila Mariana")*1) #o resultado é maior que 1, portanto
#podemos tirar a média (184 imóveis na vila mariana)
#teste
# Out:
# 184

# %%
temImoveisVilaM = (dados["Bairro"] == "Vila Mariana") #alocação da serie
temImoveisVilaM
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
dados[temImoveisVilaM] #só imprime os valores true
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveisVilaM = dados[temImoveisVilaM] #alocação dos dados da vila mariana
imoveisVilaM
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveisVilaM["Metragem"].mean() #dos dados da vila mariana, puxa a media da
#metragem
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts() #quantidade de vezes que o dataseries se repete
#por cada timeseries em ordem de decrescente
#o valor de length da series equivale quantidade de bairros total
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
numImoveisBairro = dados["Bairro"].value_counts() #locação de variável quantidade
#de imóveis por bairro
numImoveisBairro.plot.bar() #gera um grafico do tipo bar com os 701 bairros

# %%
numImoveisBairro.head(10).plot.bar() #mostra apenas os 10 primeiros itens da series

# %% [markdown]
# # 🎯 Desafios (aula 1)

# %% [markdown]
# 1.   Calcular a média da metragem dos imóveis por bairro ✔
# 2.   Procurar outras duas formas de selecionar os dados por bairro
# 3.   Procurar outras duas formas de selecionar os dados por bairro
# 4.   Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF e tentar colocar alguma conclusão da análise feita
# 5.   Pegar outras estatísticas dos dados (média, mediana, min e max) e analisar a saída
# 6.   Descobrir outras estão os valores faltantes

# %%
#Desafio 1

#Primeiramente procurei algum método que poderia relacionar cada bairro com suas
#metragens. No site "Insight", achei alguns dos métodos mais comuns utilizados em 
#Pandas  
mediaMetragemBairro = dados.groupby(["Bairro"])["Metragem"].agg("mean")
mediaMetragemBairro.sort_values(ascending=False)
# Out:
# Bairro
# Sítio Represa                         37000.000000
# Vila Castelo                           2850.000000
# Jardim Guedala                         2486.640199
# Jardim das Camélias                    1700.000000
# Chácara Flora                          1260.727273
#                                           ...
# Cidade Antônio Estevão de Carvalho       57.500000
# Jardim Nova Germania                     57.000000
# Jardim Benfica                           48.000000
# Vila Leonor                              46.000000
# Vila Guaca                               10.000000
# Name: Metragem, Length: 701, dtype: float64

# %%
mediaMetragemBairro.head(10).sort_values(ascending=False).plot.bar()

# %% [markdown]
# Bairro Barro Branco na Zona Norte possui maior média de metragem.

# %% [markdown]
# # 📘 Aula 2 - Tratamento de dados

# %%
dados.head() #ver o nome da coluna
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info() #obter o tipo da coluna valor
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Valor"][0] #coluna x linha (dataseries x time series)
# Out:
# 'R$ 7.000.000'

# %%
dados["Valor"][0].split()#separa a string e cria um array
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10) #analisar se os dados estão todos da mesma maneira
# Out:
#                           Rua                      Bairro     Cidade  \
# 3134                      NaN             Jardim Panorama  São Paulo
# 3607                      NaN  Jardim Sílvia (Zona Oeste)  São Paulo
# 118       Rua Monsenhor Moura             Vila Leopoldina  São Paulo
# 6636            Rua Jacatirão        Chácara Monte Alegre  São Paulo
# 1381  Rua Doutor Paulo Vieira                      Sumaré  São Paulo
# 4268   Avenida Lacerda Franco                     Cambuci  São Paulo
# 5060       Rua Blumenau, 105              Vila Leopoldina  São Paulo
# 4879             Rua Gassipós                Vila Mariana  São Paulo
# 3071        Rua Alberto Faria           Alto de Pinheiros  São Paulo
# 1876               Rua Araxiá              Jardim Guedala  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas          Valor
# 3134       481        4          6      4   R$ 3.500.000
# 3607      1000        5          8      8  R$ 13.000.000
# ...

# %%
dados["Valor"].str.split() #aplica o método em toda a serie, o .str. especifica que
#é do tipo string
# Out:
# 0          [R$, 7.000.000]
# 1          [R$, 3.700.000]
# 2            [R$, 380.000]
# 3            [R$, 685.000]
# 4            [R$, 540.000]
#                ...
# 10003        [R$, 665.000]
# 10004      [R$, 2.300.000]
# 10005      [R$, 1.050.000]
# 10006    [R$, 2.200, /Mês]
# 10007        [R$, 270.000]
# Name: Valor, Length: 10008, dtype: object

# %%
dados["Valor"].str.split(expand = True) #visualisar em colunas todas as variaveis nas arrays
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados["Valor"].str.split(expand = True)[0].unique() #devemos ter certeza que todas
# as linhas possuem somente um valor único, então exploramos as colunas da
# array expandida.
#Garantimos que toda coluna 0 possui o elemento 'R$'
# Out:
# array(['R$'], dtype=object)

# %%
dados["Valor"].str.split(expand = True)[1].unique() #aqui visulizamos os valores
#únicos da coluna 1 (os números)
# Out:
# array(['7.000.000', '3.700.000', '380.000', ..., '553.000', '951.000',
#        '2.200'], dtype=object)

# %%
len(dados["Valor"].str.split(expand = True)[1].unique()) #por ser muito extensa
#podemos ver qual o tamanho dela a partir do método len()

#conseguimos ver que entre os 10008 imóveis diferentes há somente 1038 preços
#diferentes, ou seja, proximdamente 9000 preços são repetidos
# Out:
# 1038

# %%
dados["Valor"].str.split(expand = True)[2].unique() #devemos garantir a coluna 2
#os dados none podem ser relcionados a venda e os dados /algo devem ser de aluguel
#----->não queremos dados de aluguel
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[["Valor", "Bairro"]] #como chamar mais de um coluna o mesmo tempo?
#crie um list dentro de [] com os dataseries da preferencia
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados[["Moeda", "Preco", "Tipo"]] = dados["Valor"].str.split(expand = True) 
#devemos adicionar esse split no nosso dataframe (considerar cada informação como um dado)

# %%
dados.head() #visualizar a adição das colunas
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda      Preco  Tipo
# 0        4          8      6  R$ 7.000.000    R$  7.000.000  None
# 1        4          4      4  R$ 3.700.000    R$  3.700.000  None
# 2        4          3      2    R$ 380.000    R$    380.000  None
# 3        3          2      4    R$ 685.000    R$    685.000  None
# 4        3          2      2    R$ 540.000    R$    540.000  None

# %%
dados["Tipo"].isnull() #vamos começar filtrando os dados de tipo
#primeiro achamos os nossos dados válidos (null por que são os de venda) e separamos-os
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10003     True
# 10004     True
# 10005     True
# 10006    False
# 10007     True
# Name: Tipo, Length: 10008, dtype: bool

# %%
dados[dados["Tipo"].isnull()] #aplicamos um máscara no dataframe só com os valores
#true da condição
dadosVendas = dados[dados["Tipo"].isnull()] #alocamos essa máscara

# %%
dados[dados["Tipo"].isnull()]["Tipo"].unique() #assim comprovamos que a series do dataframe
#realmente tem somente os dados none
# Out:
# array([None], dtype=object)

# %%
dados = dados[dados["Tipo"].isnull()] #então aplicamos a edição/máscara na tabela, terminando
#tarefa

# %%
#lembrar de ter certeza de rodar todas as coisas na ordem correta

# %%
dados #agora com a máscara
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda      Preco  \
# ...

# %%
dados.info() #preco inda é um String então devemos fazer um conversão
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6107 non-null   object
#  1   Bairro     9146 non-null   object
#  2   Cidade     9156 non-null   object
#  3   Metragem   9156 non-null   int64
#  4   Quartos    9156 non-null   int64
#  5   Banheiros  9156 non-null   int64
#  6   Vagas      9156 non-null   int64
#  7   Valor      9156 non-null   object
#  8   Moeda      9156 non-null   object
#  9   Preco      9156 non-null   object
#  10  Tipo       0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dadosVendas["Preco"].str.replace(".", "").mean #pego os dados da series preco e substituo
#os pontos nas strings por "" pra poder fazer divisão
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        7000000
# 1        3700000
# 2         380000
# 3         685000
# 4         540000
#           ...
# 10002    1500000
# 10003     665000
# 10004    2300000
# 10005    1050000
# 10007     270000
# Name: Preco, Length: 9156, dtype: object>

# %%
dadosVendas["Preco"].str.replace(".", "").astype(float) #transformo em float
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Preco, Length: 9156, dtype: float64

# %%
dadosVendas["PrecoFloat"] = dadosVendas["Preco"].str.replace(".", "").astype(float)
#adicionamos a coluna com os novos valores na máscara
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dadosVendas.info() #aqui visualizamos que temos o preco como float e é possível tirar a media
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rua         6107 non-null   object
#  1   Bairro      9146 non-null   object
#  2   Cidade      9156 non-null   object
#  3   Metragem    9156 non-null   int64
#  4   Quartos     9156 non-null   int64
#  5   Banheiros   9156 non-null   int64
#  6   Vagas       9156 non-null   int64
#  7   Valor       9156 non-null   object
#  8   Moeda       9156 non-null   object
#  9   Preco       9156 non-null   object
#  10  Tipo        0 non-null      object
#  11  PrecoFloat  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dadosVendas["PrecoFloat"].plot.hist() #geramos o gráfico da frequencia na series e o valor
#no gráfico em milhões

# %%
dadosVendas["PrecoFloat"].plot.hist(bins = 50) #bins = caixinhas

# %%
dadosVendas.describe()
#count = quantidade de elementos
#mean = médi
#std = desvio padrão
#min = mínimo
#max = máximo
#25% = quartis
#50% = mediana
#75% = outliers
# Out:
#             Metragem      Quartos    Banheiros        Vagas    PrecoFloat
# count    9156.000000  9156.000000  9156.000000  9156.000000  9.156000e+03
# mean      434.416230     3.446811     3.797073     3.960135  3.052203e+06
# std      7856.422978     1.048944     1.967873     2.601022  3.944208e+06
# min        10.000000     1.000000     1.000000     1.000000  1.300000e+04
# 25%       168.000000     3.000000     2.000000     2.000000  8.900000e+05
# 50%       276.000000     3.000000     4.000000     4.000000  1.800000e+06
# 75%       450.000000     4.000000     5.000000     5.000000  3.500000e+06
# max    750000.000000    16.000000    40.000000    50.000000  6.500000e+07

# %%
pd.set_option("display.precision",2) #define a quantidade de algarismos significativos
#que devem ser incluidos nos valores
dadosVendas.describe()
# Out:
#         Metragem  Quartos  Banheiros    Vagas  PrecoFloat
# count    9156.00  9156.00    9156.00  9156.00    9.16e+03
# mean      434.42     3.45       3.80     3.96    3.05e+06
# std      7856.42     1.05       1.97     2.60    3.94e+06
# min        10.00     1.00       1.00     1.00    1.30e+04
# 25%       168.00     3.00       2.00     2.00    8.90e+05
# 50%       276.00     3.00       4.00     4.00    1.80e+06
# 75%       450.00     4.00       5.00     5.00    3.50e+06
# max    750000.00    16.00      40.00    50.00    6.50e+07

# %%
pd.set_option("display.float_format", lambda x: '%.2f' % x) 
#também define quantidade de algarismos decimais
dadosVendas.describe()
#a partir disto conseguimos analisar os valores e ver se eles realmente fazem sentido
#para o nosso próposito
# Out:
#        Metragem  Quartos  Banheiros   Vagas  PrecoFloat
# count   9156.00  9156.00    9156.00 9156.00     9156.00
# mean     434.42     3.45       3.80    3.96  3052202.96
# std     7856.42     1.05       1.97    2.60  3944208.19
# min       10.00     1.00       1.00    1.00    13000.00
# 25%      168.00     3.00       2.00    2.00   890000.00
# 50%      276.00     3.00       4.00    4.00  1800000.00
# 75%      450.00     4.00       5.00    5.00  3500000.00
# max   750000.00    16.00      40.00   50.00 65000000.00

# %%
dadosVendas.describe(include = "all") #inclui os valores de Strings também
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
# ...

# %%
dadosVendas[["Rua", "Bairro", "Cidade"]].describe() #define somente as series que 
#se deseja ver
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
#para a visualização dos dados em gráficos vamos usar a biblioteca seaborn
import seaborn as sns
#outra biblioteca para configurar os gráficos
import matplotlib.pyplot as plt
#o seaborn está mais envolvido com a estilização e o mathplot com as configurações 

sns.set() #estiliza os gráficos

plt.figure(figsize = (10, 8)) #define o tamanho da visualização do gráfico

ax = sns.histplot(data = dadosVendas, x = "PrecoFloat", kde = True) 
#kde adiciona uma curva de aproximação

ax.set_title("Histograma Valor Imóveis") #define um título

plt.xlim((-50, 10000000)) #define  escal de x

#plotamos um gráfico, dentro da função deixamos como parâmetro os dados a serem
#inseridos e definimos o valor da abscissa
#a biblioteca já auto calculou a quantidade de bins para o caso deste gráfico específico
plt.show() #tira a linha de código que prece de default acima do gráfico

# %% [markdown]
# # 🎯 Desafios (aula 2)

# %% [markdown]
# 1.   Criar uma escala de calores em milhôes
# 2.   Deixar o gráfico do histograma de valores legíveis (alterar labels, cores título, escala)
# 3.   Preço do metro quadrado por bairro e plotar em um gráfico ideal
# 4.   Explorar as bibliotecas de visualizações e colocar as suas conclusões
# 5.   Pesquisar uma visualização para analisar os quantis, medianas e outliers

# %%
# Desafio 3
# Esta correção foi feita na aula 3
dadosVendas.head() # Aqui relembramos um pouco dos dados do projeto
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda      Preco  Tipo  PrecoFloat
# 0        4          8      6  R$ 7.000.000    R$  7.000.000  None  7000000.00
# 1        4          4      4  R$ 3.700.000    R$  3.700.000  None  3700000.00
# 2        4          3      2    R$ 380.000    R$    380.000  None   380000.00
# 3        3          2      4    R$ 685.000    R$    685.000  None   685000.00
# 4        3          2      2    R$ 540.000    R$    540.000  None   540000.00

# %%
dadosVendas["PrecoPorMetro2"] = dadosVendas["PrecoFloat"]/dadosVendas["Metragem"]
# Adiciona uma coluna na tabela de dados com os valotes de preço/m^2
dadosVendas #visualiza
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# ...

# %%
dadosVendas.groupby(["Bairro"])["PrecoPorMetro2"].mean() # Tira a média dos preços
#do metro^2 agrupados por bairro
# Out:
# Bairro
# Aclimação            7656.17
# Alto da Boa Vista    5849.57
# Alto da Lapa         7606.73
# Alto da Mooca        5691.74
# Alto de Pinheiros   11269.98
#                       ...
# Vila Água Funda      4467.13
# Água Branca          7269.11
# Água Fria            5841.10
# Água Funda           3876.86
# Água Rasa            4509.61
# Name: PrecoPorMetro2, Length: 697, dtype: float64

# %%
dadosVendas.groupby(["Bairro"]).mean() #Desta forma ele vai rodar a média de todos os
#valores possíveis da base de dados

# Porém, tirar apenas a média aritmética destes valores já divididos vai resultar
# em valores enganosos. Temos casa muito grandes e muito pequenas e preços muito
# altos e muito pequenos, assim, temos uma média muito abrangente.
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  PrecoFloat  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91  1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62  2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00  2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65  1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95  4782698.96
# ...                     ...      ...        ...    ...         ...
# Vila Água Funda      152.20     2.60       2.20   2.60   652000.00
# Água Branca          173.58     3.08       3.25   2.25  1226500.00
# Água Fria            165.42     2.83       3.42   2.50   927083.33
# Água Funda           139.00     3.00       2.50   2.00   545000.00
# Água Rasa            186.17     2.67       2.00   3.67   716166.67
#
#                    PrecoPorMetro2
# Bairro
# Aclimação                 7656.17
# Alto da Boa Vista         5849.57
# Alto da Lapa              7606.73
# ...

# %%
dadosBairro = dadosVendas.groupby(["Bairro"]).sum() 
#faz uma soma de todos os valores por bairro
dadosBairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas    PrecoFloat  \
# Bairro
# Aclimação             19447      258        240    230  139292801.00
# Alto da Boa Vista      3351       33         41     37   19130000.00
# Alto da Lapa          23940      252        308    320  166653500.00
# Alto da Mooca          5401       66         52     73   23683400.00
# Alto de Pinheiros    158616     1453       1782   1827 1764815915.00
# ...                     ...      ...        ...    ...           ...
# Vila Água Funda         761       13         11     13    3260000.00
# Água Branca            2083       37         39     27   14718000.00
# Água Fria              1985       34         41     30   11125000.00
# Água Funda              278        6          5      4    1090000.00
# Água Rasa              1117       16         12     22    4297000.00
#
#                    PrecoPorMetro2
# Bairro
# Aclimação               604837.39
# Alto da Boa Vista        46796.55
# ...

# %%
dadosBairro["ValorM2Bairro"] = dadosBairro["PrecoFloat"]/dadosBairro["Metragem"]
dadosBairro
# aqui dividimos a soma dos precos dos imoveis pela soma da metragem deles para
# obter um média mais aproximada
# Out:
#                    Metragem  Quartos  Banheiros  Vagas    PrecoFloat  \
# Bairro
# Aclimação             19447      258        240    230  139292801.00
# Alto da Boa Vista      3351       33         41     37   19130000.00
# Alto da Lapa          23940      252        308    320  166653500.00
# Alto da Mooca          5401       66         52     73   23683400.00
# Alto de Pinheiros    158616     1453       1782   1827 1764815915.00
# ...                     ...      ...        ...    ...           ...
# Vila Água Funda         761       13         11     13    3260000.00
# Água Branca            2083       37         39     27   14718000.00
# Água Fria              1985       34         41     30   11125000.00
# Água Funda              278        6          5      4    1090000.00
# Água Rasa              1117       16         12     22    4297000.00
#
#                    PrecoPorMetro2  ValorM2Bairro
# Bairro
# Aclimação               604837.39        7162.69
# ...

# %%
dadosVendas["Bairro"].value_counts() #mostra os bairro que tem mais imóveis
# Out:
# Alto de Pinheiros      369
# Jardim Guedala         353
# Jardim Paulista        266
# Brooklin Paulista      224
# Jardim Europa          210
#                       ...
# Vila Virginia            1
# Vila Boaçava             1
# Vila Agueda              1
# Jardim Monte Alegre      1
# Jardim Ivana             1
# Name: Bairro, Length: 697, dtype: int64

# %%
topBairros = dadosVendas["Bairro"].value_counts()[:10].index
#selecion penas os 10 primeiros index
#para fazer o gráfico usaremos o tipo barplot do seaborn

# %%
dadosBairro.query("Bairro in @topBairros") #busca apenas pela condição referenciada
# Out:
#                    Metragem  Quartos  Banheiros  Vagas    PrecoFloat  \
# Bairro
# Alto de Pinheiros    158616     1453       1782   1827 1764815915.00
# Brooklin Paulista     70002      778        862    832  475796789.00
# Cidade Jardim        132220      789       1008   1172 1164210900.00
# Jardim Europa        118898      795        993   1056 2414172900.00
# Jardim Guedala       972212     1443       2027   2161 1801165587.00
# Jardim Leonor         97141      697        941    902  646326369.00
# Jardim Paulista      130283     1028       1231   1171 2136081000.00
# Pacaembu             100285      774        889   1028  867956500.00
# Planalto Paulista     59250      636        768    713  374907000.00
# Vila Madalena         66250      739        786    712  583253030.00
#
#                    PrecoPorMetro2  ValorM2Bairro
# Bairro
# Alto de Pinheiros      4158622.61       11126.34
# Brooklin Paulista      1627341.87        6796.90
# ...

# %%
dadosBairro = dadosBairro.reset_index() #bairro é um index portanto fazemos um conversão
dadosBairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas    PrecoFloat  \
# 0            Aclimação     19447      258        240    230  139292801.00
# 1    Alto da Boa Vista      3351       33         41     37   19130000.00
# 2         Alto da Lapa     23940      252        308    320  166653500.00
# 3        Alto da Mooca      5401       66         52     73   23683400.00
# 4    Alto de Pinheiros    158616     1453       1782   1827 1764815915.00
# ..                 ...       ...      ...        ...    ...           ...
# 692    Vila Água Funda       761       13         11     13    3260000.00
# 693        Água Branca      2083       37         39     27   14718000.00
# 694          Água Fria      1985       34         41     30   11125000.00
# 695         Água Funda       278        6          5      4    1090000.00
# 696          Água Rasa      1117       16         12     22    4297000.00
#
#      PrecoPorMetro2  ValorM2Bairro
# 0         604837.39        7162.69
# ...

# %%
plt.figure(figsize = (10, 8)) #ajusta o tamanho
ax = sns.barplot(x = "Bairro", y = "ValorM2Bairro", 
                 data = dadosBairro.query("Bairro in @topBairros")) #plota
ax.tick_params(axis = 'x', rotation = 45) #roda as labels
#jardim europa seria o bairro mais caro
#a ordem delas é devido a ocorrencia deles em imóveis

# %%
plt.figure(figsize = (10, 8))
ax = sns.boxplot(data = dadosVendas.query("Bairro in @topBairros"), x = "Bairro", 
                 y = "PrecoFloat")
ax.tick_params(axis = 'x', rotation = 45) 
#aqui analisamos, por exemplo, o outliers de 40 banheiros e com preço fora da curva
#no bairro jardim europa

# %%
plt.figure(figsize = (10, 8))
ax = sns.boxplot(data = dadosVendas.query("Bairro in @topBairros"), x = "Bairro", 
                 y = "Metragem")
ax.tick_params(axis = 'x', rotation = 45) 
#aqui vemos que temos um outlier no próprio jrdim guedala em questão de metragem

# %%
plt.figure(figsize = (10, 8))
ax = sns.boxplot(data = dadosVendas.query("Bairro in @topBairros & Metragem<30000"), x = "Bairro", 
                 y = "Metragem") #aqui removemos o valor máximo da metragem e vemos em 
                 #uma escal bem melhor
ax.tick_params(axis = 'x', rotation = 45)

# %% [markdown]
# #📘 Aula 3 - Gráficos, Time Series e Análise Exploratória

# %% [markdown]
# Trabalhamos em cima do desafio 3 da aula 2.

# %% [markdown]
# # 🎯 Desafios (aula 3)

# %% [markdown]
# 1.   Tentar vincular dados do IBGE com os dados de imóveis
# 2.   Tratar os outliers e comparar com os resultados.
# 3.   Agrupar por mais de uma categoria e realizar as análises.

# %% [markdown]
# # 📘 Aula 4 - Cruzando base de dados

# %%
# Nesta aula precisamos ler a base de dados oferecida, limpá-la e cruzar com os
# dados das aulas anteriores
import pandas as pd
ibgeURL = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
ibgeSP = pd.read_csv(
    ibgeURL, encoding = 'ISO-8859-1', # codificador padrão da base de dados
    sep = ';', thousands = '.', decimal = ',' # definição de pontos e vírgulas
) #lendo os dados da base do IBGE
ibgeSP.dropna(how = 'all', axis = 1, inplace = True) #dropa uma coluna vazia
ibgeSP.head()
# Out:
#          Cod_setor  Cod_Grandes Regiï¿½es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                      3   Regiï¿½o Sudeste      35
# 1  355030801000002                      3   Regiï¿½o Sudeste      35
# 2  355030801000003                      3   Regiï¿½o Sudeste      35
# 3  355030801000004                      3   Regiï¿½o Sudeste      35
# 4  355030801000005                      3   Regiï¿½o Sudeste      35
#
#    Nome_da_UF   Cod_meso                  Nome_da_meso  Cod_micro  \
# 0  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 1  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 2  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 3  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 4  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
#
#   Nome_da_micro  Cod_RM  ... V003  V004    V005       V006    V007       V008  \
# ...

# %%
ibgeSP.info() #estes são os dados que temos na base do IBGE
# para conectar as informações desta base com a dos imóveis 
# vamos relacioná-las pela latitude e longitude dos endereços
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_setor              18363 non-null  int64
#  1   Cod_Grandes Regiï¿½es  18363 non-null  int64
#  2   Nome_Grande_Regiao     18363 non-null  object
#  3   Cod_UF                 18363 non-null  int64
#  4   Nome_da_UF             18363 non-null  object
#  5   Cod_meso               18363 non-null  int64
#  6   Nome_da_meso           18363 non-null  object
#  7   Cod_micro              18363 non-null  int64
#  8   Nome_da_micro          18363 non-null  object
#  9   Cod_RM                 18363 non-null  int64
#  10  Nome_da_RM             18363 non-null  object
#  11  Cod_municipio          18363 non-null  int64
#  12  Nome_do_municipio      18363 non-null  object
#  13  Cod_distrito           18363 non-null  int64
# ...

# %%
enderecos = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/enderecos.csv")
enderecos.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   tipo_logr                      logr_nome  \
# 0       Rua               Armando Silveira
# 1       Rua       João Antônio Vasconcelos
# 2       Rua  Prefeito Agenor Barcelos Feio
# 3       Rua                Sebastião Gomes
# 4       Rua            Marquês do Alegrete
#
#                                    logr_compl numero            bairro  \
# 0                        Rua Armando Silveira    NaN            Divisa
# 1  Rua João Antônio Vasconcelos - até 627/628    627           Amizade
# 2           Rua Prefeito Agenor Barcelos Feio    NaN          Registro
# 3             Rua Sebastião Gomes - até 59/60     59          Registro
# 4                     Rua Marquês do Alegrete    NaN  Parque das Águas
#
# ...

# %%
enderecosSP = enderecos.query("sigla_uf == 'SP'") #Aqui criamos um filtro 
#só pelos bairros de SP
# vamos trabalhar somento com o nome do logradouro e o tipo
enderecosSP
# Out:
#         tipo_logr                  logr_nome  \
# 1             Rua   João Antônio Vasconcelos
# 413269        Rua                          A
# 413270        Rua                          A
# 413271        Rua                          A
# 413272        Rua               João Bandini
# ...           ...                        ...
# 1113858       Rua            Daniel Buccieri
# 1113865       Rua             Ottorino Rizzi
# 1113873       Rua  Adriano Michelutti Cândia
# 1113882   Rodovia              Mario Tonolli
# 1113884       Rua                 Tiradentes
#
#                                          logr_compl numero  \
# 1        Rua João Antônio Vasconcelos - até 627/628    627
# 413269                                        Rua A    NaN
# 413270                                        Rua A    NaN
# 413271                                        Rua A    NaN
# 413272                             Rua João Bandini    NaN
# ...                                             ...    ...
# ...

# %%
enderecosSP["rua"] = enderecosSP["tipo_logr"] + " " + enderecosSP["logr_nome"]
#criando uma coluna rua 
enderecosSP["rua"] = enderecosSP["rua"].str.lower().str.strip() #ajusta os caracteres par minúsculo e retirar os espaços extras
enderecosSP.head()
#os nome das ruas não contém o número da casa portnto devemos extraí-la da base de dadosVendas
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        tipo_logr                 logr_nome  \
# 1            Rua  João Antônio Vasconcelos
# 413269       Rua                         A
# ...

# %%
dadosVendas["Rua"].str.extract(r'(^[\w ]+)')[:10] #aqui extraimos os caracteres especiais
# Out:
#                            0
# 0            Avenida Itacira
# 1  Rua Aurelia Perez Alvarez
# 2            Rua Alba Valdez
# 3                        NaN
# 4         Rua Tobias Barreto
# 5            Rua Graham Bell
# 6        Rua Francisco Paulo
# 7      Rua Guilherme Valente
# 8        Rua Sagrada Família
# 9                 Rua Tapaji

# %%
dadosVendas["apenasRua"] = dadosVendas["Rua"].str.extract(r'(^[\w ]+)') #alocamos a nova coluna
dadosVendas["apenasRua"] = dadosVendas["apenasRua"].str.lower().str.strip()
#tiramos os espaços e deixamos em lowerkey
dadosVendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# ...

# %%
dadosGeo = pd.merge(left = dadosVendas, right = enderecosSP[["rua", "cep", "latitude", "longitude"]], how = "left", left_on = "apenasRua", right_on = "rua").drop_duplicates(subset=dadosVendas.columns).query("cep > 0")
#especifica as direções da tabela, selecion um intervalo entre ela
dadosGeo
#nest tabela temos valores repetidos
#a extensão drop.duplicates retira as duplicatas de dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 5      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 6                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 7                                 NaN      Jardim Morumbi  São Paulo
# 26           Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 89956                   Avenida Odila   Planalto Paulista  São Paulo
# 89958                      Rua Tapuçu          Vila Sofia  São Paulo
# 89959                   Rua Guararema     Bosque da Saúde  São Paulo
# 89976               Rua Estero Belaco       Vila da Saúde  São Paulo
# 89977      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda      Preco  \
# ...

# %%
from shapely.geometry import Point
latitude = -23.56
longitude = -46.59
Point(longitude, latitude)
#biblioteca para trabalhar com plano de pontos

# %%
from shapely.geometry import Polygon
Polygon([[0, 0],[1, 0],[1, 1],[0, 1],[0, 0]])
Polygon([[0, 0],[1, 0],[1, 1],[0, 1],[0, 0]]).contains(Point(0.1,0.9)) #diz se o ponto está dentro da superfície criada
# Out:
# True

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import geopandas as gpd

# %%
setorCenso = gpd.read_file(
    '/content/drive/MyDrive/Colab Notebooks/sp_setores_censitarios'
)
setorCenso.head()
#aqui vemos os dados do polígono
# Out:
#         ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 0 98237.00  354100005000009  URBANO  35410000500       None  354100005
# 1 98232.00  354100005000004  URBANO  35410000500       None  354100005
# 2 98230.00  354100005000002  URBANO  35410000500       None  354100005
# 3 98229.00  354100005000001  URBANO  35410000500       None  354100005
# 4 98231.00  354100005000003  URBANO  35410000500       None  354100005
#
#      NM_DISTRIT CD_GEOCODM    NM_MUNICIP NM_MICRO                     NM_MESO  \
# 0  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 1  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 2  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 3  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 4  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
#
#      CD_GEOCODB  NM_BAIRRO  ID1  \
# 0  354100005001  Boqueirão    1
# ...

# %%
setorCensoSP = setorCenso[setorCenso.NM_MUNICIP == "SÃO PAULO"]
setorCensoSP[setorCensoSP.contains(Point(-46.63, -23.58))] #máscara de latitude e longitude
# Out:
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 60986 126568.00  355030890000080  URBANO  35503089000       None  355030890
#
#          NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 60986  VILA MARIANA    3550308  SÃO PAULO  SÃO PAULO
#
#                           NM_MESO CD_GEOCODB NM_BAIRRO    ID1  \
# 60986  METROPOLITANA DE SÃO PAULO       None      None  60987
#
#                                                 geometry
# 60986  POLYGON ((-46.62618 -23.58169, -46.62863 -23.5...

# %%
dadosGeo["Point"] = ""
for i in dadosGeo.index:
    dadosGeo["Point"][i] = Point(dadosGeo["longitude"][i], dadosGeo["latitude"][i])

dadosGeo['setor_censo'] = dadosGeo["Point"][:10].map(
    lambda x: setorCensoSP.loc[setorCensoSP.contains(x), 'CD_GEOCODI'].values
).str[0]
dadosGeo
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 5      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 6                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 7                                 NaN      Jardim Morumbi  São Paulo
# 26           Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 89956                   Avenida Odila   Planalto Paulista  São Paulo
# ...

# %%
dados_geo = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dados_geo.csv")
dados_geo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000     7000000.00           NaN
# 1        4          4      4  R$ 3.700.000     3700000.00           NaN
# 2        4          3      2    R$ 380.000      380000.00           NaN
# 3        3          2      2    R$ 540.000      540000.00           NaN
# 4        4          4      6  R$ 1.980.000     1980000.00           NaN
#
#    Valor_mm  Valor_m2                        rua        cep  latitude  \
# ...

# %%
dadosVendasCenso = pd.merge(left = dados_geo, right = ibgeSP, how = "left", left_on = "setor_censo", right_on = "Cod_setor")
dadosVendasCenso
#vinculando os dados geo/ dados ibge
#final
# Out:
#                                  Rua              Bairro     Cidade  Metragem  \
# 0              Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                    Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3           Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                    Rua Graham Bell         Santo Amaro  São Paulo       440
# ...                              ...                 ...        ...       ...
# 5600                   Avenida Odila   Planalto Paulista  São Paulo       267
# 5601                      Rua Tapuçu          Vila Sofia  São Paulo        95
# 5602                   Rua Guararema     Bosque da Saúde  São Paulo       605
# 5603               Rua Estero Belaco       Vila da Saúde  São Paulo       205
# 5604      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo       122
#
# ...

# %%
dadosVendasCenso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5605 entries, 0 to 5604
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rua                    5605 non-null   object
#  1   Bairro                 5597 non-null   object
#  2   Cidade                 5605 non-null   object
#  3   Metragem               5605 non-null   int64
#  4   Quartos                5605 non-null   int64
#  5   Banheiros              5605 non-null   int64
#  6   Vagas                  5605 non-null   int64
#  7   Valor                  5605 non-null   object
#  8   Valor_anuncio          5605 non-null   float64
#  9   Tipo_anuncio           0 non-null      float64
#  10  Valor_mm               5605 non-null   float64
#  11  Valor_m2               5605 non-null   float64
#  12  rua                    5605 non-null   object
#  13  cep                    5605 non-null   float64
# ...

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dadosVendasCenso, x="V005", y="Valor_m2")
#renda por m2

# %% [markdown]
# # 🎯 Desafios (aula 4)

# %% [markdown]
# 1.   Realizar uma análise dos dados do IBGE por mapa, analisando a distribuição de renda (https://medium.com/creditas-tech/dados-georreferenciados-explora%C3%A7%C3%A3o-e-visualiza%C3%A7%C3%A3o-com-python-edd51e7c53da)
#
# 2.   Repassar a aula para entender melhor o que foi realizado
#
# 3.   Aprofundar a análise entre dados de vendas e renda.
#
# 4.   Realizar a análise exploratória e encontrar variáveis relevantes para solução do problema.
